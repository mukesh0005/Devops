# %%
import pandas as pd

# %%
df = pd.read_csv('./SuperheroDataset.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0         Name                  Url  Intelligence  \
# 0             0           0      3-D Man     /3-d-man/10-226/          80.0
# 1             1           1       A-Bomb    /a-bomb/10-10060/          75.0
# 2             2           2   Abe Sapien  /abe-sapien/10-956/          95.0
# 3             3           3     Abin Sur   /abin-sur/10-1460/          80.0
# 4             4           4  Abomination   /abomination/10-1/          85.0
#
#    Strength  Speed  Durability  Power  Combat  ...         Height  \
# 0      35.0   45.0        35.0   25.0    55.0  ...  6'2 // 188 cm
# 1     100.0   20.0        80.0   25.0    65.0  ...  6'8 // 203 cm
# 2      30.0   35.0        65.0  100.0    85.0  ...  6'3 // 191 cm
# 3      90.0   55.0        65.0  100.0    65.0  ...  6'1 // 185 cm
# 4      80.0   55.0        90.0   65.0    95.0  ...  6'8 // 203 cm
#
#              Weight Eye color Hair color  \
# 0   200 lb // 90 kg     Brown       Grey
# ...

# %%
df.shape
# Out:
# (743, 29)

# %%
import pymongo # pymongo is a python driver for MongoDB
#import credentials # load username and password from credentials.py
connection_string = f"mongodb+srv://veeramukesh:Veerausf@clusterpilot.5llfzef.mongodb.net/?retryWrites=true&w=majority"

# %%
client = pymongo.MongoClient(connection_string)
super_heros_db = client['super_heros']

# %%
heros_collection = super_heros_db['heros']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 743 entries, 0 to 742
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0.1      743 non-null    int64
#  1   Unnamed: 0        743 non-null    int64
#  2   Name              743 non-null    object
#  3   Url               743 non-null    object
#  4   Intelligence      665 non-null    float64
#  5   Strength          665 non-null    float64
#  6   Speed             665 non-null    float64
#  7   Durability        665 non-null    float64
#  8   Power             665 non-null    float64
#  9   Combat            665 non-null    float64
#  10  Full name         743 non-null    object
#  11  Alter Egos        743 non-null    object
#  12  Aliases           743 non-null    object
#  13  Place of birth    743 non-null    object
#  14  First appearance  743 non-null    object
#  15  Creator           735 non-null    object
# ...

# %%
print(df['Alignment'].unique())
# Out:
# ['good' 'bad' '-' 'neutral']

# %%
df = df[df['Alignment'] != '`-`']

# %%
df_heros = df[df['Alignment']=='good']

# %%
df_heros.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0.1  Unnamed: 0             Name                       Url  \
# 0               0           0          3-D Man          /3-d-man/10-226/
# 1               1           1           A-Bomb         /a-bomb/10-10060/
# 2               2           2       Abe Sapien       /abe-sapien/10-956/
# 3               3           3         Abin Sur        /abin-sur/10-1460/
# 7               7           7      Adam Monroe     /adam-monroe/10-1026/
# ..            ...         ...              ...                       ...
# 737           737         737     Yellowjacket      /yellowjacket/10-70/
# 738           738         738  Yellowjacket II  /yellowjacket-ii/10-178/
# 739           739         739             Ymir             /ymir/10-179/
# 740           740         740             Yoda           /yoda/10-10454/
# 741           741         741          Zatanna          /zatanna/10-809/
#
# ...

# %%
df_villans = df[df['Alignment']=='bad']

# %%
print(df_heros.shape,df_villans.shape)
# Out:
# (499, 29) (210, 29)

# %%
df_heros.head(4)
# Out:
#    Unnamed: 0.1  Unnamed: 0        Name                  Url  Intelligence  \
# 0             0           0     3-D Man     /3-d-man/10-226/          80.0
# 1             1           1      A-Bomb    /a-bomb/10-10060/          75.0
# 2             2           2  Abe Sapien  /abe-sapien/10-956/          95.0
# 3             3           3    Abin Sur   /abin-sur/10-1460/          80.0
#
#    Strength  Speed  Durability  Power  Combat  ...         Height  \
# 0      35.0   45.0        35.0   25.0    55.0  ...  6'2 // 188 cm
# 1     100.0   20.0        80.0   25.0    65.0  ...  6'8 // 203 cm
# 2      30.0   35.0        65.0  100.0    85.0  ...  6'3 // 191 cm
# 3      90.0   55.0        65.0  100.0    65.0  ...  6'1 // 185 cm
#
#              Weight Eye color Hair color  \
# 0   200 lb // 90 kg     Brown       Grey
# 1  980 lb // 441 kg    Yellow    No Hair
# 2   145 lb // 65 kg      Blue    No Hair
# 3   200 lb // 90 kg      Blue    No Hair
#
# ...

# %%
hero_records = df_heros.to_dict(orient='records')

# %%
insert_result = heros_collection.insert_many(hero_records)

# Print the IDs of the inserted documents
print(f"Inserted document IDs: {insert_result.inserted_ids}")
# Out:
# Inserted document IDs: [ObjectId('6689408553a5d73acdd8e5eb'), ObjectId('6689408553a5d73acdd8e5ec'), ObjectId('6689408553a5d73acdd8e5ed'), ObjectId('6689408553a5d73acdd8e5ee'), ObjectId('6689408553a5d73acdd8e5ef'), ObjectId('6689408553a5d73acdd8e5f0'), ObjectId('6689408553a5d73acdd8e5f1'), ObjectId('6689408553a5d73acdd8e5f2'), ObjectId('6689408553a5d73acdd8e5f3'), ObjectId('6689408553a5d73acdd8e5f4'), ObjectId('6689408553a5d73acdd8e5f5'), ObjectId('6689408553a5d73acdd8e5f6'), ObjectId('6689408553a5d73acdd8e5f7'), ObjectId('6689408553a5d73acdd8e5f8'), ObjectId('6689408553a5d73acdd8e5f9'), ObjectId('6689408553a5d73acdd8e5fa'), ObjectId('6689408553a5d73acdd8e5fb'), ObjectId('6689408553a5d73acdd8e5fc'), ObjectId('6689408553a5d73acdd8e5fd'), ObjectId('6689408553a5d73acdd8e5fe'), ObjectId('6689408553a5d73acdd8e5ff'), ObjectId('6689408553a5d73acdd8e600'), ObjectId('6689408553a5d73acdd8e601'), ObjectId('6689408553a5d73acdd8e602'), ObjectId('6689408553a5d73acdd8e603'), ObjectId('6689408553a5d7
# ...

# %%
villan_collection = super_heros_db['villans']

# %%
villan_records = df_villans.to_dict(orient='records')
insert_result = villan_collection.insert_many(villan_records)

# Print the IDs of the inserted documents
print(f"Inserted document IDs: {insert_result.inserted_ids}")
# Out:
# Inserted document IDs: [ObjectId('6689408753a5d73acdd8e7de'), ObjectId('6689408753a5d73acdd8e7df'), ObjectId('6689408753a5d73acdd8e7e0'), ObjectId('6689408753a5d73acdd8e7e1'), ObjectId('6689408753a5d73acdd8e7e2'), ObjectId('6689408753a5d73acdd8e7e3'), ObjectId('6689408753a5d73acdd8e7e4'), ObjectId('6689408753a5d73acdd8e7e5'), ObjectId('6689408753a5d73acdd8e7e6'), ObjectId('6689408753a5d73acdd8e7e7'), ObjectId('6689408753a5d73acdd8e7e8'), ObjectId('6689408753a5d73acdd8e7e9'), ObjectId('6689408753a5d73acdd8e7ea'), ObjectId('6689408753a5d73acdd8e7eb'), ObjectId('6689408753a5d73acdd8e7ec'), ObjectId('6689408753a5d73acdd8e7ed'), ObjectId('6689408753a5d73acdd8e7ee'), ObjectId('6689408753a5d73acdd8e7ef'), ObjectId('6689408753a5d73acdd8e7f0'), ObjectId('6689408753a5d73acdd8e7f1'), ObjectId('6689408753a5d73acdd8e7f2'), ObjectId('6689408753a5d73acdd8e7f3'), ObjectId('6689408753a5d73acdd8e7f4'), ObjectId('6689408753a5d73acdd8e7f5'), ObjectId('6689408753a5d73acdd8e7f6'), ObjectId('6689408753a5d7
# ...

# %%
for doc in villan_collection.find():
    print(doc)
# Out:
# {'_id': ObjectId('6689408753a5d73acdd8e7de'), 'Unnamed: 0.1': 4, 'Unnamed: 0': 4, 'Name': 'Abomination', 'Url': '/abomination/10-1/', 'Intelligence': 85.0, 'Strength': 80.0, 'Speed': 55.0, 'Durability': 90.0, 'Power': 65.0, 'Combat': 95.0, 'Full name': 'Emil Blonsky', 'Alter Egos': 'Abomination (MCU)', 'Aliases': 'Agent R-7, Ravager of Worlds', 'Place of birth': 'Zagreb, Yugoslavia', 'First appearance': 'Tales to Astonish #90', 'Creator': 'Marvel Comics', 'Alignment': 'bad', 'Gender': 'Male', 'Race': 'Human / Radiation', 'Height': "6'8 // 203 cm", 'Weight': '980 lb // 441 kg', 'Eye color': 'Green', 'Hair color': 'No Hair', 'Occupation': 'Ex-Spy', 'Base': 'Mobile', 'Team Affiliation': 'Annihilators (Leader), Wrecking Crew, Masters of Evil, Superiour Six, New Enforcers, Secret Empire, Formerly: The Mighty Avengers', 'Relatives': 'Nadia Dornova Blonsky (wife, separated)', 'Skin color': nan, 'Total Power': 470.0}
# ...

# %%
for doc in heros_collection.find():
    print(doc)
# Out:
# {'_id': ObjectId('6689408553a5d73acdd8e5eb'), 'Unnamed: 0.1': 0, 'Unnamed: 0': 0, 'Name': '3-D Man', 'Url': '/3-d-man/10-226/', 'Intelligence': 80.0, 'Strength': 35.0, 'Speed': 45.0, 'Durability': 35.0, 'Power': 25.0, 'Combat': 55.0, 'Full name': 'Charles Chandler', 'Alter Egos': 'No alter egos found.', 'Aliases': '-', 'Place of birth': '-', 'First appearance': '-', 'Creator': 'Marvel Comics', 'Alignment': 'good', 'Gender': 'Male', 'Race': '-', 'Height': "6'2 // 188 cm", 'Weight': '200 lb // 90 kg', 'Eye color': 'Brown', 'Hair color': 'Grey', 'Occupation': 'Test pilot, adventurer', 'Base': '-', 'Team Affiliation': 'Agents of Atlas, Asgardians, Formerly: Avengers', 'Relatives': 'Hal Chandler (brother), Peggy Clark (sister-in-law), Chuck (nephew), Hal Jr (nephew), unnamed parents', 'Skin color': nan, 'Total Power': 275.0}
# ...

# %%
for doc in heros_collection.find({'Name': 'Flash'}):
    print(doc)
# Out:
# {'_id': ObjectId('6689408553a5d73acdd8e698'), 'Unnamed: 0.1': 261, 'Unnamed: 0': 261, 'Name': 'Flash', 'Url': '/flash/10-891/', 'Intelligence': 85.0, 'Strength': 10.0, 'Speed': 100.0, 'Durability': 50.0, 'Power': 70.0, 'Combat': 35.0, 'Full name': 'Jason Peter Garrick', 'Alter Egos': 'The Flash (CW)', 'Aliases': 'Jay Garrick, Siegfreid the Speedster', 'Place of birth': 'Hibbardsville, Kansas', 'First appearance': 'Flash Comics #1 (January 1940)', 'Creator': 'DC Comics', 'Alignment': 'good', 'Gender': 'Male', 'Race': 'Human', 'Height': "5'11 // 180 cm", 'Weight': '179 lb // 81 kg', 'Eye color': 'Blue', 'Hair color': 'Brown / White', 'Occupation': 'Research Scientist, part-time Director of Garrick Laboratories', 'Base': 'Keystone City, Kansas', 'Team Affiliation': 'Flash Family, All-Star Squadron, Justice Legion Alpha, Formerly: Justice League', 'Relatives': 'Joseph Garrick (father), Joan Williams (wife), Arthur Williams (father-in-law), unnamed adopted son (deceased), Bart Allen (Flas
# ...

# %%
for doc in villan_collection.find({'Name': 'Darkseid'}):
    print(doc)
# Out:
# {'_id': ObjectId('6689408753a5d73acdd8e814'), 'Unnamed: 0.1': 204, 'Unnamed: 0': 204, 'Name': 'Darkseid', 'Url': '/darkseid/10-668/', 'Intelligence': 95.0, 'Strength': 100.0, 'Speed': 85.0, 'Durability': 100.0, 'Power': 100.0, 'Combat': 95.0, 'Full name': 'Uxas', 'Alter Egos': 'Darkseid (Anti-Life Equation), Darkseid (New 52), Darkseid (True Form)', 'Aliases': 'Dark God', 'Place of birth': '-', 'First appearance': "Superman's Pal Jimmy Olsen #134 (November 1970)", 'Creator': 'DC Comics', 'Alignment': 'bad', 'Gender': 'Male', 'Race': 'New God', 'Height': "8'9 // 267 cm", 'Weight': '1815 lb // 817 kg', 'Eye color': 'Red', 'Hair color': 'No Hair', 'Occupation': 'Dictator of Apokolips', 'Base': '-', 'Team Affiliation': 'New Gods of Apokolips (Leader), Secret Society of Super-Villains', 'Relatives': 'Zonuz (father), Izaya (brother), Avia (sister, deceased), Grail (daughter), Kalibak (son), Orion (son), Deathspawn (son), Scot (nephew/adopted son)', 'Skin color': 'Grey', 'Total Power': 575.
# ...
